# %%
#Q1. What is a random variable in probability theory?
A random variable is a numerical value assigned to the outcomes of a random experiment.

Example: In a coin toss, let Heads = 1 and Tails = 0. The result becomes a random variable.

# %% [markdown]
# #Q1. What is a random variable in probability theory?
# A random variable is a numerical value assigned to the outcomes of a random experiment.
#
# Example: In a coin toss, let Heads = 1 and Tails = 0. The result becomes a random variable.
#
# #Q2. What are the types of random variables?
# Discrete Random Variable: Takes countable values (e.g., number of heads).
#
# Continuous Random Variable: Takes uncountably infinite values over an interval (e.g., height, weight).
#
# #Q3. What is the difference between discrete and continuous distributions?
# Discrete Distribution: Deals with countable outcomes (e.g., binomial).
#
# Continuous Distribution: Deals with outcomes over a continuous range (e.g., normal distribution).
#
# #Q4. What are probability distribution functions (PDF)?
# A PDF gives the probability density for a continuous random variable.
#
# Area under the curve = probability over that interval.
#
# #Q5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
# PDF: Shows likelihood at specific points (height of the curve).
#
# CDF: Shows probability up to a value (area under the curve):
# CDF(x)=P(X≤x)
#
# #Q6. What is a discrete uniform distribution?
# A distribution where all outcomes are equally likely.
#
# Example: Rolling a fair die – each face has probability 1/6.
#
# #Q7. What are the key properties of a Bernoulli distribution?
# Single trial with two outcomes: 1 (success) with probability p, 0 (failure) with probability 1-p.
#
# Mean = p, Variance = p(1 – p)
#
# #Q8. What is the binomial distribution, and how is it used in probability?
# Models k successes in n independent Bernoulli trials.
#
# Parameters: n (trials), p (probability of success).
#
# Used in yes/no outcome problems like coin tosses, surveys.
# #Q9. What is the Poisson distribution and where is it applied?
# Models the number of events in a fixed interval of time/space given a constant rate.
#
# Parameter: λ (mean events per interval)
#
# Example: number of calls in a call center per hour.
#
# #Q10. What is a continuous uniform distribution?
# All values in an interval [a, b] have equal probability density.
# 𝑓(𝑥)=1/(b-a)
#
# #Q11. What are the characteristics of a normal distribution?
# Bell-shaped and symmetric around the mean.
#
# Described by mean (μ) and standard deviation (σ).
#
# 68% within 1σ, 95% within 2σ, 99.7% within 3σ.
#
# #Q12. What is the standard normal distribution, and why is it important?
# Normal distribution with mean = 0 and standard deviation = 1.
#
# Used to standardize values and perform Z-score calculations.
#
# #Q13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# The CLT states that the sampling distribution of the sample mean becomes approximately normal, even if the population is not, when the sample size is large (n ≥ 30).
#
# Critical for inferential statistics.
#
# #Q14. How does the Central Limit Theorem relate to the normal distribution?
# It explains why the normal distribution is so commonly used—because averages of many samples follow it, even if the original data is not normal.
#
# #Q15. What is the application of Z statistics in hypothesis testing?
# Helps determine whether to reject a null hypothesis.
#
# Used when population standard deviation is known.
#
# #Q16. How do you calculate a Z-score, and what does it represent?
# Z= (X−μ)/sigma
# It tells how many standard deviations a value is from the mean.
#
# #Q17.What are point estimates and interval estimates in statistics?
# Point Estimate: Single value estimate (e.g., sample mean).
#
# Interval Estimate: Range of values (e.g., confidence interval) likely to contain the true population parameter.
#
# #Q18. What is the significance of confidence intervals in statistical analysis?
# A confidence interval gives a range that is likely to include the true population parameter, with a certain confidence level (e.g., 95%).
#
# #Q19. What is the relationship between a Z-score and a confidence interval?
# Confidence intervals use Z-scores as cutoffs for the range:
# x ±Z⋅ (σ/√n)
#
# #Q20. How are Z-scores used to compare different distributions?
# They standardize different datasets so you can compare across different scales (e.g., test scores with different means and standard deviations).
#
# #Q21. What are the assumptions for applying the Central Limit Theorem?
# Independent and identically distributed samples.
#
# Finite variance and mean.
#
# Large sample size (usually n ≥ 30).
#
# #Q22. What is the concept of expected value in a probability distribution?
# It is the average value we expect from a random variable:
# Discrete:
# E[X] = Σ (xi * P(xi)) from i = 1 to n
#
# #Q23. How does a probability distribution relate to the expected outcome of a random variable?
#
# The distribution determines the likelihood of different outcomes, and from this, the expected value is calculated as the average result over many repetitions.
